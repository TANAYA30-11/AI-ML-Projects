# %%
print("hello")
# Out:
# hello

# %%
print("how are you")
# Out:
# how are you

# %%
def hello():
  print("hello how are you")

# %%
hello()
# Out:
# hello how are you

# %% [markdown]
# # New Section
